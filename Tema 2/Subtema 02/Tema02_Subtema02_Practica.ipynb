# %% [markdown]
# # Vectores
# ## Descomponer un Vector
#
# **Asignatura:** Física Universitaria (Mecánica Newtoniana)
#
# **Autor:** Esteban Sango | La Academia

# %% [markdown]
# ## Ejercicio 01
# ¿Cuáles son las componentes $x$ y $y$ del vector $\vec{D}$ en la figura?
# La magnitud del vector es $D = 3.00 \, \text{m}$ y el ángulo es $\alpha = 45^\circ$.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Solución 01
# Añadir solución.

# %%
# Ingrese su código aquí 👽.

# %% [markdown]
# ## Ejercicio 02
# ¿Cuáles son las componentes $x$ y $y$ del vector $\vec{E}$ en la figura?
# La magnitud del vector es $E = 4.50 \, \text{m}$ y el ángulo es $\beta = 37^\circ$.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Solución 02
# Añadir solución.

# %%
# Ingrese su código aquí 👽.
